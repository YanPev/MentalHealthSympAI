# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/master/courses/AI_in_medicine/AI_MD_Project
# Out:
# /content/drive/MyDrive/master/courses/AI_in_medicine/AI_MD_Project

# %%
# !python src/data/download_edaic_data.py

# %%
# !python src/data/inspect_edaic_week1.py
# Out:
# \nPossible participant ID columns:
# - Participant_ID
# \nPossible PHQ-related columns:
# - PHQ_8NoInterest
# - PHQ_8Depressed
# - PHQ_8Sleep
# - PHQ_8Tired
# - PHQ_8Appetite
# - PHQ_8Failure
# - PHQ_8Concentrating
# - PHQ_8Moving
# - PHQ_8Total
# \nPHQ-8 total column found: PHQ_8Total
# \nConfirmed PHQ-8 item-level columns:
# - PHQ_8NoInterest
# - PHQ_8Depressed
# - PHQ_8Sleep
# - PHQ_8Tired
# - PHQ_8Appetite
# - PHQ_8Failure
# - PHQ_8Concentrating
# - PHQ_8Moving
# \nPHQ-8 item value ranges:
# PHQ_8NoInterest -> [0, 1, 2, 3]
# PHQ_8Depressed -> [0, 1, 2, 3]
# PHQ_8Sleep -> [0, 1, 2, 3]
# PHQ_8Tired -> [0, 1, 2, 3]
# PHQ_8Appetite -> [0, 1, 2, 3]
# PHQ_8Failure -> [0, 1, 2, 3]
# PHQ_8Concentrating -> [0, 1, 2, 3]
# PHQ_8Moving -> [0, 1, 2, 3]
# \nMissing values per PHQ-8 item:
# PHQ_8NoInterest       0
# PHQ_8Depressed        0
# PHQ_8Sleep            0
# PHQ_8Tired            0
# PHQ_8Appetite         0
# PHQ_8Failure          0
# PHQ_8Concentrating    0
# PHQ_8Moving           0
# ...

# %%
from pathlib import Path

PROJECT_DIR = Path("/content/drive/MyDrive/master/courses/AI_in_medicine/AI_MD_Project")
NOTEBOOKS_DIR = PROJECT_DIR / "notebooks"
NOTEBOOKS_DIR.mkdir(parents=True, exist_ok=True)

print(NOTEBOOKS_DIR)
# Out:
# /content/drive/MyDrive/master/courses/AI_in_medicine/AI_MD_Project/notebooks
